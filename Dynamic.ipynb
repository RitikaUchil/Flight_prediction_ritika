# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import accuracy_score,r2_score,mean_absolute_error,mean_squared_error
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor,GradientBoostingRegressor
# !pip install xgboost
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
import pickle as pk
import numpy as np
from sklearn.neighbors import KNeighborsRegressor
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
df=pd.read_excel("Data_Train.xlsx")

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
le=LabelEncoder()
df["Airline"]=le.fit_transform(df["Airline"])
df["Source"]=le.fit_transform(df["Source"])
df["Destination"]=le.fit_transform(df["Destination"])
df["Route"]=le.fit_transform(df["Route"])
df["Date_of_Journey"]=le.fit_transform(df["Date_of_Journey"])
df["Dep_Time"]=le.fit_transform(df["Dep_Time"])
df["Arrival_Time"]=le.fit_transform(df["Arrival_Time"])
df["Duration"]=le.fit_transform(df["Duration"])
df["Total_Stops"]=le.fit_transform(df["Total_Stops"])
df["Additional_Info"]=le.fit_transform(df["Additional_Info"])

# %%
df.head()
# Out:
#    Airline  Date_of_Journey  Source  Destination  Route  Dep_Time  \
# 0        3               24       0            5     18       211
# 1        1                6       3            0     84        31
# 2        4               43       2            1    118        70
# 3        3               10       3            0     91       164
# 4        3                0       0            5     29       149
#
#    Arrival_Time  Duration  Total_Stops  Additional_Info  Price
# 0           233       240            4                8   3897
# 1           906       336            1                8   7662
# 2           413       106            1                8  13882
# 3          1324       311            0                8   6218
# 4          1237       303            0                8  13302

# %%
x_train,x_test,y_train,y_test=train_test_split(df.drop("Price",axis=1),df["Price"],test_size=0.33,random_state=40)

# %% [markdown]
# Decision Tree Regression

# %%
dt = DecisionTreeRegressor()
dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dt.predict(x_test)

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.7737450211858543

# %% [markdown]
# Linear Regression

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 2694.985316763167

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.335412040469649

# %% [markdown]
# Ridge

# %%
rg=Ridge(alpha=10)
rg.fit(x_train,y_train)
# Out:
# Ridge(alpha=10)

# %%
y_pred=rg.predict(x_test)

# %%
print(f"alpha:10,parameters of b1,b2,b3:{rg.coef_},accuracy{r2_score(y_test,y_pred)}")
# Out:
# alpha:10,parameters of b1,b2,b3:[-2.21732719e+01 -1.04537533e+01 -3.06624732e+02  1.91372660e+02
#  -5.05118792e+00  2.52451829e+00 -3.91392695e-01 -3.07566840e+00
#  -1.59661850e+03  1.82721770e+02],accuracy0.335398591441637

# %% [markdown]
# Lasso

# %%
la=Lasso(alpha=10)
la.fit(x_train,y_train)
# Out:
# Lasso(alpha=10)

# %%
y_pred=la.predict(x_test)

# %%
print(f"alpha:10,parameters of b1,b2,b3:{la.coef_},accuracy{r2_score(y_test,y_pred)}")
# Out:
# alpha:10,parameters of b1,b2,b3:[-2.06322763e+01 -1.05774510e+01 -3.00528252e+02  1.87273521e+02
#  -5.08068170e+00  2.49809246e+00 -3.89140254e-01 -3.06895209e+00
#  -1.59182655e+03  1.75292965e+02],accuracy0.3353337572223962

# %% [markdown]
# Random Forest

# %%
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
x_train.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info'],
#       dtype='object')

# %%
y_pred=rf.predict(x_test)

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.8437866182651604

# %%
mse = mean_absolute_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 839.923643409208

# %%
xg=XGBRegressor()
xg.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred=xg.predict(x_test)

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.8590518832206726

# %%
mse = mean_absolute_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 844.9505257955411

# %% [markdown]
# Support Vector Machine

# %%
svr_model = SVR(kernel='rbf')
svr_model.fit(x_train, y_train)
# Out:
# SVR()

# %%
y_pred=xg.predict(x_test)

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.8590518832206726

# %% [markdown]
# Gradient Boosting Regressor

# %%
gb_model = GradientBoostingRegressor(n_estimators=100)
gb_model.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred=xg.predict(x_test)

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.8590518832206726

# %% [markdown]
# MLP Regressor

# %%
mlp_model = MLPRegressor(hidden_layer_sizes=(50, 50))
mlp_model.fit(x_train, y_train)
# Out:
# C:\Users\Ritika\AppData\Roaming\Python\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPRegressor(hidden_layer_sizes=(50, 50))

# %%
y_pred=xg.predict(x_test)

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.8590518832206726

# %% [markdown]
# K_Nearest_Neighorhood

# %%
knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred = knn.predict(x_test)

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.556887738202329

# %%
df.head()
# Out:
#    Airline  Date_of_Journey  Source  Destination  Route  Dep_Time  \
# 0        3               24       0            5     18       211
# 1        1                6       3            0     84        31
# 2        4               43       2            1    118        70
# 3        3               10       3            0     91       164
# 4        3                0       0            5     29       149
#
#    Arrival_Time  Duration  Total_Stops  Additional_Info  Price
# 0           233       240            4                8   3897
# 1           906       336            1                8   7662
# 2           413       106            1                8  13882
# 3          1324       311            0                8   6218
# 4          1237       303            0                8  13302

# %% [markdown]
# filename="RandomForest_model.sav"
# pk.dump(rf,open(filename,"wb"))
# loaded_model=pk.load(open(filename,"rb"))
# input_data=[[4,43,2,1,118,70,413,106,1,8]]
# prediction=loaded_model.predict(input_data)
# print("Prediction:",prediction)

# %% [markdown]
# rg,dt,lr,mlp_model,model,xg,knn,la,rf,svr_model,gb_model,gb_model,dt

# %%
import joblib

joblib.dump(rf, "random_forest_model.pkl")
# Out:
# ['random_forest_model.pkl']
